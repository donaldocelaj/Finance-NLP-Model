# %%
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
import numpy as np
import ast
import numpy as np

# %%
#Here are a list of words that, when preceding, require us to inverse our score. 
#"I like Apple" has a score of 1.5, but "I don't like Apple" would have a score of -1.5 because of the negation
negate = \
    ["aint", "arent", "cannot", "cant", "couldnt", "darent", "didnt", "doesnt",
     "ain't", "aren't", "can't", "couldn't", "daren't", "didn't", "doesn't",
     "dont", "hadnt", "hasnt", "havent", "isnt", "mightnt", "mustnt", "neither",
     "don't", "hadn't", "hasn't", "haven't", "isn't", "mightn't", "mustn't",
     "neednt", "needn't", "never", "none", "nope", "nor", "not", "nothing", "nowhere",
     "oughtnt", "shant", "shouldnt", "uhuh", "wasnt", "werent",
     "oughtn't", "shan't", "shouldn't", "uh-uh", "wasn't", "weren't",
     "without", "wont", "wouldnt", "won't", "wouldn't", "rarely", "seldom", "despite"]

boosters = \
    ['absolutely', 'astonishingly', 'amazingly', 'greatly', 'completely', 'considerably', 'decidedly', 'deeply', 'effing',
     'enormously', 'exceedingly', 'supremely', 'strikingly', 'vastly', 'notably', 'surpassingly', 'terrifically',
     'immensely', 
     'entirely', 'especially', 'exceptionally', 'extremely', 'fabulously', 'flipping', 'flippin', 'fricking', 'frickin',
     'frigging', 'friggin', 'fully', 'fucking', 'greatly', 'hella', 'highly', 'hugely', 'incredibly', 'intensely', 'majorly',
     'more', 'most', 'particularly', 'purely', 'quite', 'really', 'remarkably', 'so', 'surprisingly', 'substantially',
     'thoroughly', 'totally', 'tremendously', 'uber', 'unbelievably', 'unusually', 'utterly', 'very']

decreasers = \
['almost', 'barely', 'scarcily', 'lacking', 'hardly', 'kind of', 'kinda', 'less', 'little', 'marginally', 'occasionally', 
 'partly', 'sort of',
'sorta', 'hardly', 'slightly', 'carelessly', 'somewhat', 'in part', 'relatively', 'not entirely', 'not fully',]

# %%
def create_ci_lexicon(lexicon_file):
    
    """
    Takes in an inital lexicon with information on how the final values was derived.
    Outputs confidence score for each individual word.
    """
    
    df = pd.read_csv(lexicon_file, encoding='cp437', header=None)
    
    def descriptive(x):
        return np.std(ast.literal_eval(x))
    
    df['std_dev'] = df[3].str.strip("'").apply(descriptive)
    
    basis = df.std_dev.mean() + 1.5 * df.std_dev.std()
    
    def normalize_conf(x):
        return (x - basis) / basis
    
    df['norm_conf'] = df.std_dev.apply(normalize_conf)
    
    return dict(zip(df[[0, 'norm_conf']][0].values, (1 - (df.norm_conf.rank() / df.norm_conf.rank().max()))))

# %%
ci_lexicon = create_ci_lexicon('HiddenAlphabet_lexicon.csv')
lexicon = dict(zip(pd.read_csv('HiddenAlphabet_lexicon.csv', 
                               encoding='cp437', 
                               header=None)[[0, 1]].values.T[0], 
                   pd.read_csv('HiddenAlphabet_lexicon.csv', 
                               encoding='cp437', 
                               header=None)[[0, 1]].values.T[1]))

# %%
class PreprocessText(object):
    """
    Sentiment relevant text properties. 
    """

    def __init__(self, text):

        self.text = text
        self.clean_text = self._clean_text()

    def _clean_text(self):

        wordz = self.text.split()

        lemmatizer = WordNetLemmatizer()
        words = []
        for word in wordz:
            words.append(lemmatizer.lemmatize(word))

        return words

# %%
class Sentiment(object):
    """
    Sentiment Analyzer
    """


    def __init__(self):

        self.lexicon = lexicon
        self.negate = negate
        self.ci_lexicon = ci_lexicon
        self.boosters = boosters
        self.decreasers = decreasers
            
    def score(self, text):
        """Calculate sentiment score for text"""
        words = PreprocessText(text).clean_text
        sentiments = []
        confidences = []
        for item in words:
            sentiments, confidences = self.sentiment_polarity(item, sentiments, confidences, words)
        score_interval = self.final_calculation(sentiments, confidences)
        
        return {'score': score_interval[0], 'confidence_interval': score_interval[1]}
        
    def sentiment_polarity(self, item, sentiments, confidences, words):
        """Checks the average sentiment score by querying our lexicon"""
        item_lowercase = item.lower()
        if item_lowercase in self.lexicon:
            weight = self.lexicon[item_lowercase] / 5 
            final_weight = self.modifiers(words, item, weight)
            confidence_score = self.ci_lexicon[item_lowercase]
            confidence_calc = self.confidence_calc(final_weight, confidence_score)
            sentiments.append(final_weight)
            confidences.append(confidence_calc)
        return sentiments, confidences
    
    
    def final_calculation(self, sentiments, confidences):
        """Applies all final calculations to get the final sentiment score"""
        
        if len(sentiments) == 0:
            final_calc = 0
            return final_calc, (0, 0)
        else:
            final_calc = sum(sentiments) / len(sentiments)
        
        count = 0
        upper = 0
        lower = 0
        for interv in confidences:
            upper += interv[1]
            lower += interv[0]
            count += 1
        
        return final_calc, (lower/count, upper/count)
    
    def modifiers(self, words, item, weight):
        """Checks to see if there is a negation word in the words
        I love apples = .72
        I don't love apples = -.72"""
        neg_coef = 1
        boost_coef = 1
        dec_coef = 1
        lexicon_index = words.index(item)
        preceding_word = words[lexicon_index - 1]
        if preceding_word in self.negate:
            neg_coef = -1
        if preceding_word in self.boosters:
            boost_coef = 1.25
        if preceding_word in self.decreasers:
            dec_coef = .8
        final_weight = weight * neg_coef * boost_coef * dec_coef
        return final_weight
    
    
    def confidence_calc(self, final_weight, confidence_score): 
        
        if final_weight >= 0:
            upper = final_weight + (1 - confidence_score) * final_weight
            lower = final_weight - (1 - confidence_score) * final_weight
        else: 
            lower = final_weight + (1 - confidence_score) * final_weight
            upper = final_weight - (1 - confidence_score) * final_weight
        return (lower, upper)

# %%
engine = db.create_engine('postgresql+psycopg2://don:dumbass5@mydb.c44ugb8jww48.us-east-2.rds.amazonaws.com:5432/postgres')
connection = engine.connect()
metadata = db.MetaData()
testtable = db.Table('sample_tweets2', metadata, autoload=True, autoload_with=engine)
query = db.select([testtable])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
df = pd.DataFrame(ResultSet)
df.columns = ResultSet[0].keys()
df['sentiment_score'] = df['sentiment_score'].astype('float64')

# %%
df[(df['time'] > '2019-06-14') & (df['time'] <= '2019-06-15')]
# Out:
#       field1                                               text  \
# 7885   61781  Market Stats at End of Day $SPY $ES_F $IWM htt...
# 8557   62229  $SPY clear  289.19 and hold above  get fast ru...
# 8841   62230     $VIX LOD, $SPY may spike here in "Power hour!"
# 9714   30877  Sold #TRADING #FOLLOWTHEBULL #SPREADTRADING #S...
# 11721  30878  Sold #TRADING #FOLLOWTHEBULL #SPREADTRADING #S...
# 11927  30879  Sold #TRADING #FOLLOWTHEBULL #SPREADTRADING #S...
# 12050  30880  Sold #TRADING #FOLLOWTHEBULL #SPREADTRADING #S...
# 12588  30881  Sold #TRADING #FOLLOWTHEBULL #SPREADTRADING #S...
# 12630  30965  #BuenosDiasATodos   #trading  #forex 📉😉 https:...
# 13043  31831  ‘Monopoly’-Style #BlockchainProperty #Trading ...
# 13207  32089  6 Ways to Kill It at a Singles Party https://t...
# 13533  32376  #Geldverdienen im #Internet mit #Forex #Tradin...
# 16842  46892  Really don’t like this open/action on #ES_F re...
# 17043  46893  $VIX is not at high of day with #ES_F at the o...
# 17202  46975  $ES_F 15 min bearish rising wedge...\n\n\n\n$S...
# 17284  46976  $AAPL trading system. Simple Swing: https://t....
# 27098  27666  El dólar sube ante el euro y cierra mixto ante...
# 27218  27667  FOREX TRADING - Probably My BEST TRADING Video...
# 27300  27903  $FLKS back to $.20s\n\n#stocks #stockmarkets #...
# 27524  27894  BTCUSD order books live! #crypto #trading @bin...
# 27719  27943  Do not quit on yourself!\n#fxdivabou #forex #t...
# 27753  27660  RT @WingGirlTrade: FREE SIMULATED PAPER TRADIN...
# 27754  27661  RT @WingGirlTrade: FREE SIMULATED PAPER TRADIN...
# 27755  27662  https://t.co/uAcamO9vH1 alerted options gainin...
# 27756  27663  RT @CRESIOcoin: BECAUSE WE'RE DIFFERENT. SOLUT...
# 27757  27664  @dexentralize estará abierta a Productores de ...
# 27758  27665  Descubre en que estamos trabajando en @dexentr...
# 27759  27668  😎🏖🍷 \n#ibiza\n#freedom #finance #forex #forexl...
# 27760  27669  Market Guru Speaks -- George Soros- Learn How ...
# 27761  27670  This just shows that I need to always trust my...
# ...      ...                                                ...
# 63876  63862  #Data says Data isn't new. #Google #Salesforce...
# 63877  63863  Some things I look out for:\n\n#stockstowatch ...
# 63878  63864  RT @ElaineBenes99: Still here! $ES_F $SPX $SPY...
# 63879  63865  $TLT The #Fed Won't Cut, Not Next Week, Next M...
# 63880  63866  RT @TheBubbleBubble: A Morgan Stanley index of...
# 63881  63867  RT @Guruleaks1: CFA Institute Says Record Numb...
# 63882  63868  $GS Boo Hoo Goldman Sachs…It’s Not Easy Being ...
# 63883  63869  Still here! $ES_F $SPX $SPY\n\nIn keeping with...
# 63884  63870  $ZS $VEEV $PLAN  $XSW $SPY  \n\n  \n\nTop Rank...
# 63885  63871  #MarketTiming - back to across-the-board buy s...
# 63886  63872  RT @warrior16win: @t4kingoff $HDii have been 💥...
# 63887  63873  $ZB_F / $TLT Treasuries continuing to show str...
# 63888  63874  $VXX $TVIX $SVXY $SLV $GLD $QQQ $DJIA $DIA $SP...
# 63889  63875  RT @marketminute: Tdy I tweeted that this mkt ...
# 63890  63876  RT @macrohedged: Here are the #Volatility leve...
# 63891  63877  RT @davidsettle42: 06/13/19 - View today's #Ma...
# 63892  63878  RT @marketminute: Tdy I tweeted that this mkt ...
# 63893  63879  RT @marketminute: Tdy I tweeted that this mkt ...
# 63894  63880  $ES_F $SPY $SPX Only makes sense for the marke...
# 63895  63881  My indicator summary $SPY: net indicators lean...
# 63896  63882  RT @macrohedged: Here are the #Volatility leve...
# 63897  63883  RT @macrohedged: Good morning Asia, here are t...
# 63898  63884  RT @seeitmarket: NEW Article: "A Mound of Debt...
# 63899  63885  RT @davidsettle42: 06/13/19 - View today's #Ma...
# 63900  63886  RT @davidsettle42: 06/13/19 - View today's #Ma...
# 63901  63887  Bigs doing better but still have to pop the to...
# 63902  63888                   $SPY 293.32 break next objective
# 63903  63889  @marketminute Mish makes sense , good read. I ...
# 63904  63890  RT @charliebilello: Ratio of Small Caps to Lar...
# 63905  63891  RT @warrior16win: @t4kingoff $HDii have been 💥...
#
#                       time  sentiment_score
# 7885   2019-06-14 22:00:01             0.00
# 8557   2019-06-14 18:52:37             0.32
# 8841   2019-06-14 18:52:04             0.00
# 9714   2019-06-14 09:55:19             0.00
# 11721  2019-06-14 09:55:19             0.00
# 11927  2019-06-14 09:55:19             0.00
# 12050  2019-06-14 09:55:18             0.00
# 12588  2019-06-14 09:55:18             0.00
# 12630  2019-06-14 09:31:48             0.00
# 13043  2019-06-14 05:55:31             0.00
# 13207  2019-06-14 04:00:57            -0.20
# 13533  2019-06-14 02:00:39             0.00
# 16842  2019-06-14 13:40:04             0.30
# 17043  2019-06-14 13:38:55            -0.22
# 17202  2019-06-14 06:16:51             0.00
# 17284  2019-06-14 06:15:57             0.00
# 27098  2019-06-14 23:53:12             0.00
# 27218  2019-06-14 23:53:05             0.64
# 27300  2019-06-14 21:44:34             0.00
# 27524  2019-06-14 21:47:48             0.00
# 27719  2019-06-14 21:30:57             0.00
# 27753  2019-06-14 23:59:58             0.46
# 27754  2019-06-14 23:57:47             0.46
# 27755  2019-06-14 23:57:26             0.30
# 27756  2019-06-14 23:57:25             0.14
# 27757  2019-06-14 23:55:12             0.00
# 27758  2019-06-14 23:54:44             0.00
# 27759  2019-06-14 23:52:29             0.00
# 27760  2019-06-14 23:52:27             0.38
# 27761  2019-06-14 23:52:14             0.46
# ...                    ...              ...
# 63876  2019-06-14 00:21:32             0.00
# 63877  2019-06-14 00:21:16             0.00
# 63878  2019-06-14 00:21:01             0.00
# 63879  2019-06-14 00:20:17             0.00
# 63880  2019-06-14 00:19:46             0.00
# 63881  2019-06-14 00:19:46             0.06
# 63882  2019-06-14 00:19:23             0.08
# 63883  2019-06-14 00:18:59             0.00
# 63884  2019-06-14 00:18:33             0.16
# 63885  2019-06-14 00:17:50             0.00
# 63886  2019-06-14 00:17:28            -0.24
# 63887  2019-06-14 00:16:07             0.30
# 63888  2019-06-14 00:15:31             0.00
# 63889  2019-06-14 00:14:04            -0.18
# 63890  2019-06-14 00:12:30             0.36
# 63891  2019-06-14 00:10:30             0.00
# 63892  2019-06-14 00:08:03            -0.18
# 63893  2019-06-14 00:06:38            -0.18
# 63894  2019-06-14 00:05:39             0.00
# 63895  2019-06-14 00:03:45             0.00
# 63896  2019-06-14 00:03:21             0.36
# 63897  2019-06-14 00:03:17             0.38
# 63898  2019-06-14 00:02:44             0.00
# 63899  2019-06-14 00:02:36             0.00
# 63900  2019-06-14 00:02:26             0.00
# 63901  2019-06-14 00:02:13             0.27
# 63902  2019-06-14 00:02:12             0.00
# 63903  2019-06-14 00:01:36             0.38
# 63904  2019-06-14 00:00:44            -0.32
# 63905  2019-06-14 00:00:37            -0.24
#
# [7536 rows x 4 columns]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dir(SentimentIntensityAnalyzer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_amplify_ep',
#  '_amplify_qm',
#  '_but_check',
#  '_idioms_check',
#  '_least_check',
#  '_never_check',
#  '_punctuation_emphasis',
#  '_sift_sentiment_scores',
#  'make_lex_dict',
#  'polarity_scores',
#  'score_valence',
#  'sentiment_valence']

# %%
def vectorized_sentiment(text):
    try:
        return model.score(text)['score']
    except:
        return 0

# %%
def vader_sentiment(text):
    try:
        return model2.polarity_scores(text)['compound']
    except:
        return 0

# %%
vectorized_sentiment("The scooter craze is purely hype")
# Out:
# -0.12

# %%
vader_sentiment("The scooter craze is purely hype")
# Out:
# -0.1531

# %%
model = Sentiment()

# %%
df = pd.read_csv('trading-tweets.csv')

# %%
df['our_scores'] = df.text.apply(vectorized_sentiment)

# %%
df['vader_scores'] = df.text.apply(vader_sentiment)

# %%
df[['text','our_scores','vader_scores']]
# Out:
#                                                     text  our_scores  \
# 0      RT @maya_preferred: Wow 🔥\nMaya Preferred 223 ...    0.420000
# 1      $USDCAD has been slammed over the last 4 #trad...   -0.040000
# 2      $USDJPY has hit a 5-month low of 107.0696 at 0...    0.030000
# 3      $NZDUSD has hit a week high of 0.66 at 04:15 o...    0.280000
# 4      RT @MartinRapaport: #HongKong fair opens with ...    0.340000
# 5      RT @myforexeye: 📊Trade Call 📉|#EURINR |#Sell a...    0.000000
# 6      An Ok! Day \n\nDone for the day , again lovely...    0.700000
# 7      RT @SiptoSlurrency: Verbalizing my thoughts ar...   -0.240000
# 8      RT @murthaburke: Let's go South Korea!! @authp...    0.000000
# 9      RT @murthaburke: Look how easy it is to Mine X...    0.380000
# 10     🌊$PVT to Launch on MXC\n\n🌟Trading at \n      ...    0.000000
# 11     RT @murthaburke: Why use torrents over Google ...    0.000000
# 12                #Gold #trading https://t.co/XAF5oP3GTA    0.000000
# 13     RT @murthaburke: Look forward because JULY 15t...    0.000000
# 14     RT @CreditTerra: Credit Trading Competition is...    0.440000
# 15     GOLD at a level last seen August 2013. Global ...    0.000000
# 16     It is a winning day for $NUGT and $JNUG holder...    0.150000
# 17     https://t.co/bqTKi67iw0 Make your money grow w...    0.000000
# 18     RT @BlackBoxStocks: Yesterday’s BlackBox Optio...    0.380000
# 19     RT @elitexcrypto: The day has arrived! EliteX ...    0.280000
# 20     #Nifty fut shorted at 11825.. SL 840\n\nTarget...   -1.000000
# 21     RT @bennchi2010: Exklusive kostenloses Online-...    0.000000
# 22     RT @ForexinWorld: $USDNOK 🇺🇸🇳🇴 down 🔻 from 8.7...    0.000000
# 23     RT @bennchi2010: Exklusive kostenloses Online-...    0.000000
# 24     Test our #SMS #Signal #Trading #Alert,  #USDHK...    0.430000
# 25     Target 1 Achieved on Zeel\n\n#Trading #Positio...    0.000000
# 26     Weekend video will cover new data, new charts,...    0.000000
# 27     Follow #Pepperstone #FX ChrisWeston_ps' #tweet...    0.000000
# 28         Looks like #nifty50 losing Momentum. #Trading   -0.010000
# 29     RT @Creeptohunk: The first usage of the term D...   -0.660000
# ...                                                  ...         ...
# 69078  RT @alpepinnazzo: #Brazil is the new safe heav...    0.126667
# 69079  RT @Sandro_power: $SPY update I talk about to ...    0.597500
# 69080  RT @Code430Lives: It’s doing that thing again ...    0.060000
# 69081  International stocks just can’t compete with t...    0.000000
# 69082                     @Sandro_power $spy  key levels    0.000000
# 69083  RT @Sandro_power: $SPY update I talk about to ...    0.597500
# 69084  $dji #es_f  $spy $es #options  #spx edge of gr...    0.000000
# 69085  RT @bespokeinvest: Updated charts of "buy the ...    0.000000
# 69086  RT @bespokeinvest: Updated charts of "buy the ...    0.000000
# 69087  $SPY Top of the BF next likely target 294-295 ...    0.160000
# 69088  #ES_F \n\n\n\n2895 should be tough resistance ...   -0.100000
# 69089  $SPY all targets met / took off / all day post...    0.260000
# 69090  Half of $SPY Trade#4 gone at 2:02 PM  https://...    0.000000
# 69091     $SPY $DIA $QQQ Shorts crushed, bull run intact    0.160000
# 69092  RT @Sandro_power: $SPY update I talk about to ...    0.597500
# 69093  RT @MadMraket: $AYX looks very good . Good LT ...    0.443333
# 69094  $SPY looks like the impatient investors took p...    0.146667
# 69095  RT @bespokeinvest: Updated charts of "buy the ...    0.000000
# 69096  RT @TimCGriffith: @RampCapitalLLC The title do...    0.000000
# 69097  $STMH Huge bids in all of a sudden. Micro floa...    0.300000
# 69098  Are you interested in options? Trading neutral...    0.340000
# 69099  RT @jomama_trades: Potential stick saves? 🏒\n\...    0.000000
# 69100  #Trump y la trampa a cuenta de los listos en e...    0.000000
# 69101  RT @BrodmannOTC: $BEMG ---- Lines about to tou...    0.000000
# 69102                                     $SPY let's go!    0.000000
# 69103  Added .97 Cost basis all 1.26 $SPY June 14 290...    0.000000
# 69104  RT @TicTocTick: Folks: I am only 400 followers...    0.400000
# 69105  Idk but cut those rates and pump $spy https://...   -0.150000
# 69106  Short puts strategies can increase the average...    0.205000
# 69107  RT @MacroCharts: Equity vs Bond flows have hit...    0.420000
#
#        vader_scores
# 0            0.6239
# 1           -0.4215
# 2           -0.2732
# 3            0.0000
# 4            0.7964
# 5            0.0000
# 6            0.8748
# 7           -0.2960
# 8            0.0000
# 9            0.4404
# 10           0.0000
# 11           0.0000
# 12           0.0000
# 13           0.0000
# 14           0.7506
# 15           0.0000
# 16           0.4199
# 17           0.0000
# 18           0.8617
# 19           0.0000
# 20           0.0000
# 21           0.0000
# 22           0.0000
# 23           0.0000
# 24           0.7430
# 25           0.0000
# 26           0.0000
# 27           0.0000
# 28          -0.0258
# 29          -0.6486
# ...             ...
# 69078        0.4404
# 69079        0.8268
# 69080       -0.5574
# 69081        0.0000
# 69082        0.0000
# 69083        0.8268
# 69084        0.0000
# 69085        0.0000
# 69086        0.0000
# 69087        0.2023
# 69088       -0.1280
# 69089        0.4648
# 69090        0.0000
# 69091       -0.2500
# 69092        0.8268
# 69093        0.8792
# 69094        0.4939
# 69095        0.0000
# 69096        0.0000
# 69097        0.6124
# 69098        0.4696
# 69099        0.0000
# 69100        0.0000
# 69101        0.0000
# 69102        0.0000
# 69103        0.0000
# 69104        0.7184
# 69105       -0.4310
# 69106        0.7269
# 69107        0.0000
#
# [69108 rows x 3 columns]

# %%
df.to_csv('comparing_models.csv')

# %%
model2 = SentimentIntensityAnalyzer()

# %%
model2.polarity_scores('hey')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
